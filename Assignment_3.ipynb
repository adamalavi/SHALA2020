# %% [markdown]
# <a href="https://colab.research.google.com/github/adamalavi/SHALA2020/blob/master/Assignment_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Assignment - 3: Improving Graphs**
#
# ---
# Course website: [SHALA-2020](https://shala2020.github.io/)
#
# This assignment will get you familiarized with improving plots/graphs in Python.

# %% [markdown]
# ---
# ## Part 1 - Importing packages and loading data
# ---

# %% [markdown]
# ###Import the following libraries:
#
# * ```numpy``` with an alias name ```np```,
# * ```pandas``` with an alias name ```pd```,
# * ```matplotlib.pyplot``` with an alias name ```plt```, and
# * ```seaborn``` with an alias name ```sns```.
#
# *You are free to use any other popular libraries*.

# %%
# Load the libraries with their aliases 
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Using the files ```train.csv``` and ```moviesData.csv```,  peform the following:
#
# * Load these file as ```pandas``` dataframes and store it in variables named ```train``` and ```movies``` respectively.
# * Print the first ten rows of ```train``` and last ten rows of ```movies```.

# %%
# Load train.csv and movies.csv 
url_train = "https://raw.githubusercontent.com/shala2020/shala2020.github.io/master/Lecture_Materials/Assignments/DataScience/L2/train.csv"
train = pd.read_csv(url_train)

# Print the first ten rows of train
train.head(10)
# Out:
#    Age  Attrition     BusinessTravel  DailyRate              Department  \
# 0   41          1      Travel_Rarely       1102                   Sales
# 1   49          0  Travel_Frequently        279  Research & Development
# 2   37          1      Travel_Rarely       1373  Research & Development
# 3   33          0  Travel_Frequently       1392  Research & Development
# 4   27          0      Travel_Rarely        591  Research & Development
# 5   32          0  Travel_Frequently       1005  Research & Development
# 6   59          0      Travel_Rarely       1324  Research & Development
# 7   30          0      Travel_Rarely       1358  Research & Development
# 8   38          0  Travel_Frequently        216  Research & Development
# 9   36          0      Travel_Rarely       1299  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
# 5                 2          2  Life Sciences              1               8
# 6                 3          3        Medical              1              10
# 7                24          1  Life Sciences              1              11
# 8                23          3  Life Sciences              1              12
# 9                27          3        Medical              1              13
#
#    EnvironmentSatisfaction  Gender  HourlyRate  JobInvolvement  JobLevel  \
# 0                        2  Female          94               3         2
# 1                        3    Male          61               2         2
# 2                        4    Male          92               2         1
# 3                        4  Female          56               3         1
# 4                        1    Male          40               3         1
# 5                        4    Male          79               3         1
# 6                        3  Female          81               4         1
# 7                        4    Male          67               3         1
# 8                        4    Male          44               2         3
# 9                        3    Male          94               3         2
#
#                      JobRole  JobSatisfaction MaritalStatus  MonthlyIncome  \
# 0            Sales Executive                4        Single           5993
# 1         Research Scientist                2       Married           5130
# 2      Laboratory Technician                3        Single           2090
# 3         Research Scientist                3       Married           2909
# 4      Laboratory Technician                2       Married           3468
# 5      Laboratory Technician                4        Single           3068
# 6      Laboratory Technician                1       Married           2670
# 7      Laboratory Technician                3      Divorced           2693
# 8     Manufacturing Director                3        Single           9526
# 9  Healthcare Representative                3       Married           5237
#
#    MonthlyRate  NumCompaniesWorked OverTime  PercentSalaryHike  \
# 0        19479                   8      Yes                 11
# 1        24907                   1       No                 23
# 2         2396                   6      Yes                 15
# 3        23159                   1      Yes                 11
# 4        16632                   9       No                 12
# 5        11864                   0       No                 13
# 6         9964                   4      Yes                 20
# 7        13335                   1       No                 22
# 8         8787                   0       No                 21
# 9        16577                   6       No                 13
#
#    PerformanceRating  RelationshipSatisfaction  StockOptionLevel  \
# 0                  3                         1                 0
# 1                  4                         4                 1
# 2                  3                         2                 0
# 3                  3                         3                 0
# 4                  3                         4                 1
# 5                  3                         3                 0
# 6                  4                         1                 3
# 7                  4                         2                 1
# 8                  4                         2                 0
# 9                  3                         2                 2
#
#    TotalWorkingYears  TrainingTimesLastYear  WorkLifeBalance  YearsAtCompany  \
# 0                  8                      0                1               6
# 1                 10                      3                3              10
# 2                  7                      3                3               0
# 3                  8                      3                3               8
# 4                  6                      3                3               2
# 5                  8                      2                2               7
# 6                 12                      3                2               1
# 7                  1                      2                3               1
# 8                 10                      2                3               9
# 9                 17                      3                2               7
#
#    YearsInCurrentRole  YearsSinceLastPromotion  YearsWithCurrManager  ID
# 0                   4                        0                     5   0
# 1                   7                        1                     7   1
# 2                   0                        0                     0   2
# 3                   7                        3                     0   3
# 4                   2                        2                     2   4
# 5                   7                        3                     6   5
# 6                   0                        0                     0   6
# 7                   0                        0                     0   7
# 8                   7                        1                     8   8
# 9                   7                        7                     7   9

# %%
# Load movies.csv
url_movies = "https://raw.githubusercontent.com/shala2020/shala2020.github.io/master/Lecture_Materials/Google_Colab_Notebooks/DataScience/L2/moviesData.csv"
movies = pd.read_csv(url_movies)

# Print the last ten rows of movies 
movies.head(10)
# Out:
#    Unnamed: 0                   title    title_type        genre  runtime  \
# 0           1             Filly Brown  Feature Film        Drama     80.0
# 1           2                The Dish  Feature Film        Drama    101.0
# 2           3     Waiting for Guffman  Feature Film       Comedy     84.0
# 3           4    The Age of Innocence  Feature Film        Drama    139.0
# 4           5             Malevolence  Feature Film       Horror     90.0
# 5           6             Old Partner   Documentary  Documentary     78.0
# 6           7               Lady Jane  Feature Film        Drama    142.0
# 7           8            Mad Dog Time  Feature Film        Drama     93.0
# 8           9  Beauty Is Embarrassing   Documentary  Documentary     88.0
# 9          10    The Snowtown Murders  Feature Film        Drama    119.0
#
#   mpaa_rating                    studio  thtr_rel_year  thtr_rel_month  \
# 0           R       Indomina Media Inc.           2013               4
# 1       PG-13     Warner Bros. Pictures           2001               3
# 2           R    Sony Pictures Classics           1996               8
# 3          PG         Columbia Pictures           1993              10
# 4           R  Anchor Bay Entertainment           2004               9
# 5     Unrated        Shcalo Media Group           2009               1
# 6       PG-13      Paramount Home Video           1986               1
# 7           R        MGM/United Artists           1996              11
# 8     Unrated      Independent Pictures           2012               9
# 9     Unrated                 IFC Films           2012               3
#
#    thtr_rel_day  dvd_rel_year  dvd_rel_month  dvd_rel_day  imdb_rating  \
# 0            19        2013.0            7.0         30.0          5.5
# 1            14        2001.0            8.0         28.0          7.3
# 2            21        2001.0            8.0         21.0          7.6
# 3             1        2001.0           11.0          6.0          7.2
# 4            10        2005.0            4.0         19.0          5.1
# 5            15        2010.0            4.0         20.0          7.8
# 6             1        2003.0            2.0         18.0          7.2
# 7             8        2004.0            3.0          2.0          5.5
# 8             7        2013.0            1.0         21.0          7.5
# 9             2        2012.0            8.0         14.0          6.6
#
#    imdb_num_votes   critics_rating  critics_score audience_rating  \
# 0             899           Rotten             45         Upright
# 1           12285  Certified Fresh             96         Upright
# 2           22381  Certified Fresh             91         Upright
# 3           35096  Certified Fresh             80         Upright
# 4            2386           Rotten             33         Spilled
# 5             333            Fresh             91         Upright
# 6            5016           Rotten             57         Upright
# 7            2272           Rotten             17         Spilled
# 8             880            Fresh             90         Upright
# 9           12496  Certified Fresh             83         Upright
#
#    audience_score best_pic_nom best_pic_win best_actor_win best_actress_win  \
# 0              73           no           no             no               no
# 1              81           no           no             no               no
# 2              91           no           no             no               no
# 3              76           no           no            yes               no
# 4              27           no           no             no               no
# 5              86           no           no             no               no
# 6              76           no           no             no               no
# 7              47           no           no            yes               no
# 8              89           no           no             no               no
# 9              66           no           no             no               no
#
#   best_dir_win top200_box           director             actor1  \
# 0           no         no   Michael D. Olmos     Gina Rodriguez
# 1           no         no          Rob Sitch          Sam Neill
# 2           no         no  Christopher Guest  Christopher Guest
# 3          yes         no    Martin Scorsese   Daniel Day-Lewis
# 4           no         no        Stevan Mena      Samantha Dark
# 5           no         no    Chung-ryoul Lee      Choi Won-kyun
# 6           no         no        Trevor Nunn         Cary Elwes
# 7           no         no       Larry Bishop   Richard Dreyfuss
# 8           no         no      Neil Berkeley       Paul Reubens
# 9           no         no      Justin Kurzel     Lucas Pittaway
#
#                actor2                actor3            actor4  \
# 0        Jenni Rivera  Lou Diamond Phillips     Emilio Rivera
# 1    Kevin Harrington     Patrick Warburton          Tom Long
# 2    Catherine O'Hara          Parker Posey       Eugene Levy
# 3   Michelle Pfeiffer          Winona Ryder  Richard E. Grant
# 4  R. Brandon Johnson       Brandon Johnson     Heather Magee
# 5        Lee Sam-soon                   Moo               NaN
# 6           John Wood       Michael Hordern   Jill Bennett II
# 7       Jeff Goldblum         Gabriel Byrne      Ellen Barkin
# 8       Matt Groening           Todd Oldham   Jonathan Dayton
# 9     Daniel Henshall         Louise Harris       Craig Coyne
#
#                  actor5
# 0   Joseph Julian Soria
# 1        Genevieve Mooy
# 2           Bob Balaban
# 3          Alec McCowen
# 4        Richard Glover
# 5                   NaN
# 6  Helena Bonham Carter
# 7            Diane Lane
# 8        Cliff Benjamin
# 9         Richard Green

# %% [markdown]
# ---
# ## Part 2 - Drawing correlation and heatmap
# ---

# %% [markdown]
# ### Using the correlation matrix, peform the following:
#
# * Find the correlation matrix for the ```movies```.
# * Draw a **heatmap** with the correlation matrix and display the values of correlation coefficients for each pair of features. Make sure the values are properly visible. You might want to adjust the figure size for this.
# * Create a ```mask``` to remove the duplicate values from the **heatmap**.

# %%
# Find out the correlation matrix 
corr_mat = movies.corr()
# Draw the heatmap 
fig, ax = plt.subplots(figsize=(15,15))
mask_mat = np.triu(corr_mat)
sns.heatmap(corr_mat, ax=ax, annot=True, mask=mask_mat)

# %% [markdown]
# ---
# ## Part 3 - Drawing plots and customizing these
# ---

# %% [markdown]
# ### Using a histogram, peform the following:
#
# * Draw a histogram of all the numeric features in ```train```. Please note that this can be done in a single command.
#
# * Find out whether there is any redundant features in ```train```, which can be dropped while building a model.

# %%
# Draw a histogram 
train._get_numeric_data().hist(bins=15, figsize=(25, 25), grid=False, alpha=0.8);
# Find out the redundant features 
# Some of the redundant features according to the graph are:
# 1. EmployeeCount 
# 2. Employee Number
# 3. ID

# %% [markdown]
# ### Using a scatter plot, perform the following:
#
# * Draw a scatter plot between between ```imdb_rating``` and ```audience_score```, and also fit a regression line.
# * Change the color of marker to red, size to 200, transparency to 0.3.

# %%
# Scatter plot to fit the regression line 
fig, ax = plt.subplots(figsize=(16,8))
sns.regplot(x='audience_score', y='imdb_rating', data=movies, ax=ax)

# %%
# Change marker of the scatter plot
fig, ax = plt.subplots(figsize=(16,8))
sns.regplot(x='audience_score', y='imdb_rating', data=movies, ax=ax, scatter_kws={'s': 200, 'color': 'red', 'alpha': 0.3})

# %% [markdown]
# ### Using a scatter plot, perform the following:
#
# * Load the dataset ```iris```. This has been done for you.
# * Draw a scatter plot between between ```petal_length``` and ```petal_width``` and color it according to the ```species```.
# * Change the size of marker to 100 and place the legend in ```lower right```.

# %%
# library & dataset
import seaborn as sns
df = sns.load_dataset("iris")
df.head()
# Use the 'hue' argument to provide a factor variable
fig, ax = plt.subplots(figsize=(16,8))
sns.scatterplot('petal_length', 'petal_width', data=df, hue='species', ax=ax, s=150)
 
# Move the legend to an empty part of the plot
plt.legend(loc = "lower right")

# %% [markdown]
# ---
# ## Part 4 - Density Plots
# ---

# %% [markdown]
# ### Using density plots, perform the following:
#
# * Load the dataset ```iris```. This has been done for you.
# * Draw the density plots for all the features ```sepal_width```, ```sepal_length```, ```petal_width```, and ```petal_length```. You can required to use subplots for plotting all the density plots.
# * Try drawing a [CDF](https://en.wikipedia.org/wiki/Cumulative_distribution_function) of these features. There is a [blog on medium](https://medium.com/@rishav.jnit/exploratory-data-analysis-eda-on-iris-dataset-using-python-cadd850c1fc6) on how to plot CDF. It will be covered in tutorial.

# %%
df = sns.load_dataset('iris')
fig, ax = plt.subplots(figsize=(10,10))
plt.subplot(2,2,1)
sns.kdeplot(df['sepal_width'], shade=True, color = 'blue')
plt.subplot(2,2,2)
sns.kdeplot(df['sepal_length'], shade=True, color = 'red')
plt.subplot(2,2,3)
sns.kdeplot(df['petal_width'], shade=True, color = 'orange')
plt.subplot(2,2,4)
sns.kdeplot(df['petal_length'], shade=True, color = 'green')

# %%
# library and dataset 
df = sns.load_dataset('iris')
fig, ax = plt.subplots(figsize=(10,10))
plt.subplot(2,2,1)
sns.kdeplot(df['sepal_width'], shade=True, color = 'blue', cumulative=True)
plt.subplot(2,2,2)
sns.kdeplot(df['sepal_length'], shade=True, color = 'red', cumulative=True)
plt.subplot(2,2,3)
sns.kdeplot(df['petal_width'], shade=True, color = 'orange', cumulative=True)
plt.subplot(2,2,4)
sns.kdeplot(df['petal_length'], shade=True, color = 'green', cumulative=True)

# %% [markdown]
# ### Using violin plot, perform the following:
#
# * Load the dataset ```iris```. This has been done for you.
# * Draw the density plots of ```species``` versus ```sepal_length```.
# * Assign each group a color like
#
#     * versicolor - green,
#     * setosa - blue,
#     * virginica - m

# %%
# Draw the normal violin plots 
fig, ax = plt.subplots(figsize=(8,8))
sns.violinplot(x='species', y='sepal_length', data=df)

# %%
# Change the color of each group 
fig, ax = plt.subplots(figsize=(8,8))
sns.violinplot(x='species', y='sepal_length', data=df, palette={"versicolor":"g", "setosa":"b", "virginica":"m"})
